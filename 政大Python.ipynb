# %%
'Fuck'+'Yeah'
# Out:
# 'FuckYeah'

# %%
1+1
# Out:
# 2

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([1,2,3,4,5],[-2,10,3,5,15])

# %%
plot(sin(pi/2))

# %%
radn(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b016fb8cd2df> in <module>()
# ----> 1 radn(10)
#
# NameError: name 'radn' is not defined

# %%
randn(10)
# Out:
# array([ 1.35406444, -1.08226331,  1.69186571,  0.23603109, -0.05658589,
#        -1.62599382,  0.71873417,  0.22702137, -0.26267056, -0.36919393])

# %%
plot(randn(100))

# %% [markdown]
# 靠杯

# %%
# 爽
## 爽爽
### 爽爽爽

# %% [markdown]
# # 爽
# ## 爽爽
# ### 爽爽爽

# %% [markdown]
# # 分項說明
#
# ## 內容 :
# *A
# *B
# *C

# %% [markdown]
# * A
# * B
# * C

# %% [markdown]
# # sdfsd
# ## fdfsdfsdf

# %% [markdown]
# # sdfsdfs
# ## sdasd

# %%
1234
# Out:
# 1234

# %% [markdown]
# to code by Y

# %%
1234
# Out:
# 1234

# %% [markdown]
# 1234
